# %% [markdown]
# <a href="https://colab.research.google.com/github/zera888/Image_process/blob/MachineLearning-100days/2021_10_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import ImageFont, ImageDraw, Image
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
import time

m1=cv2.imread("1.jpg",1)

th, m2=cv2.threshold(m1, 127, 255, cv2.THRESH_BINARY)
print(th)
cv2_imshow(m1)
cv2_imshow(m2)

th, m2[:,:,0]=cv2.threshold(m1[:,:,0], 0, 255, cv2.THRESH_BINARY|cv2.THRESH_OTSU)
print(th)
th, m2[:,:,1]=cv2.threshold(m1[:,:,1], 0, 255, cv2.THRESH_BINARY|cv2.THRESH_OTSU)
print(th)
th, m2[:,:,2]=cv2.threshold(m1[:,:,2], 0, 255, cv2.THRESH_BINARY|cv2.THRESH_OTSU)
print(th)
cv2_imshow(m2)

print(m2)

# %%
from PIL import ImageFont, ImageDraw, Image
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
import time

m1=cv2.imread("1.jpg",1)

m2=m1.copy()
m2[:,:,0]=cv2.adaptiveThreshold(
  m1[:,:,0],255,cv2.ADAPTIVE_THRESH_MEAN_C,
  cv2.THRESH_BINARY,15,-2
)
m2[:,:,1]=cv2.adaptiveThreshold(
  m1[:,:,1],255,cv2.ADAPTIVE_THRESH_MEAN_C,
  cv2.THRESH_BINARY,15,-2
)
m2[:,:,2]=cv2.adaptiveThreshold(
  m1[:,:,2],255,cv2.ADAPTIVE_THRESH_MEAN_C,
  cv2.THRESH_BINARY,15,-2
)
cv2_imshow(m1)
cv2_imshow(m2)

# %%
from PIL import ImageFont, ImageDraw, Image
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
import time

m1=cv2.imread("1.jpg",1)

m2=cv2.Canny(m1,100,200)

m3=cv2.blur(m1,(55,55))
m4=cv2.medianBlur(m1,55)

cv2_imshow(m1)
cv2_imshow(m2)
cv2_imshow(m3)
cv2_imshow(m4)

# %%
from PIL import ImageFont, ImageDraw, Image
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
import time

m1=cv2.imread("3.jpg",1)
m2=m1.copy()
m2[:,:,0]=cv2.equalizeHist(m1[:,:,0])
m2[:,:,1]=cv2.equalizeHist(m1[:,:,1])
m2[:,:,2]=cv2.equalizeHist(m1[:,:,2])

cv2_imshow(m1)
cv2_imshow(m2)

# %%
from PIL import ImageFont, ImageDraw, Image
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
import time

m1=cv2.imread("05-1.png",1)


m2=cv2.dilate(m1,np.ones((2,1)))
m2=cv2.erode(m2,np.ones((2,1)))

# m2=cv2.morphologyEx(m1, cv2.MORPH_CLOSE, np.ones((2,1)))

cv2_imshow(m1)
cv2_imshow(m2)

# %%
from PIL import ImageFont, ImageDraw, Image
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
import time

m1=cv2.imread("5.png",1)

# m2=cv2.inRange(m1, (0,0,0), (50,50,50))
m2=cv2.inRange(m1, (200,200,200), (255,255,255))
m2=cv2.cvtColor(m2,cv2.COLOR_GRAY2BGR)
m3=cv2.add(m1,m2)

cv2_imshow(m1)
cv2_imshow(m2)
cv2_imshow(m3)

# %%
from PIL import ImageFont, ImageDraw, Image
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
import time

m1=cv2.imread("6.png",1)

m2=cv2.inRange(m1, (0,0,0), (50,50,50))
m2=cv2.bitwise_not(m2)
m3=cv2.inRange(m1, (30,200,200), (80,255,255))
m3=cv2.bitwise_not(m3)
m4=cv2.bitwise_and(m2,m3)
m4=cv2.erode(m4,np.ones((2,2)))

m4=cv2.cvtColor(m4,cv2.COLOR_GRAY2BGR)
m5=cv2.add(m1,m4)

# cv2_imshow(m1)
# cv2_imshow(m2)
# cv2_imshow(m3)
# cv2_imshow(m4)
cv2_imshow(m5)

# %%
from PIL import ImageFont, ImageDraw, Image
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
import time

m1=cv2.imread("7.png",1)
m2=cv2.inRange(m1, (200,200,200), (255,255,255))
a, b=cv2.findContours(m2,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
print("輪廓數量：",len(a))
maxIndex=1
for i in range(2,len(a),1):
  x1, y1, w1, h1 =cv2.boundingRect(a[i])
  x2, y2, w2, h2 =cv2.boundingRect(a[maxIndex])
  if w1*h1>w2*h2:
    maxIndex=i
  
# cv2.rectangle(m1, (x,y), (x+w,y+h), (0,0,255), 2)
m3=np.full(m1.shape,(255,255,255),np.uint8)
cv2.drawContours(m3,a,maxIndex,(0,0,0),-1)
m3=cv2.add(m1,m3)

cv2_imshow(m1)
# cv2_imshow(m2)
cv2_imshow(m3)

# %%
from PIL import ImageFont, ImageDraw, Image
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
import time

m1=cv2.imread("8.png",1)
m2=cv2.inRange(m1, (200,200,200), (255,255,255))
m2=cv2.erode(m2,np.ones((2,20)))
a, b=cv2.findContours(m2,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
print("輪廓數量：",len(a))

for i in range(0,len(a),1):
  x1, y1, w1, h1 =cv2.boundingRect(a[i])
  if w1>h1*3:
    m3=np.full(m1.shape,(255,255,255),np.uint8)
    cv2.drawContours(m3,a,i,(0,0,0),-1)

m3=cv2.add(m1,m3)

cv2_imshow(m1)
cv2_imshow(m2)
cv2_imshow(m3)

# %%
# !apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
# !pip install pytesseract

# %%
from PIL import ImageFont, ImageDraw, Image
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
import time
import pytesseract as pt

m1=cv2.imread("9.png",1)
text=pt.image_to_string(m1,"eng","")
print("辨識出來的問字：",text)
cv2_imshow(m1)

# %%
from PIL import ImageFont, ImageDraw, Image
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
import time
import pytesseract as pt

m1=cv2.imread("5.jpg",1)
m2=cv2.inRange(m1, (0,0,0), (50,50,50))
m2=cv2.dilate(m2,np.ones((3,25)))
a, b=cv2.findContours(m2,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
print("輪廓數量：",len(a))

maxIndex=0
for i in range(1,len(a),1):
  x1, y1, w1, h1 =cv2.boundingRect(a[i])
  x2, y2, w2, h2 =cv2.boundingRect(a[maxIndex])
  if w1*h1>w2*h2:
    maxIndex=i

m3=np.full(m1.shape,(255,255,255),np.uint8)
cv2.drawContours(m3,a,maxIndex,(0,0,0),-1)
m3=cv2.add(m1,m3)

text=pt.image_to_string(m3,"eng","")
print("辨識出來的問字：",text)
cv2_imshow(m1)
cv2_imshow(m2)
cv2_imshow(m3)

# %%
from PIL import ImageFont, ImageDraw, Image
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
import time
import pytesseract as pt

m1=cv2.imread("5.jpg",1)
m2=cv2.inRange(m1, (0,0,0), (50,50,50))
m2=cv2.dilate(m2,np.ones((3,25)))
a, b=cv2.findContours(m2,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
print("輪廓數量：",len(a))

middle=int(m1.shape[0]/2)
center=int(m1.shape[1]/2)
minIndex=0
for i in range(1,len(a),1):
  x1, y1, w1, h1 =cv2.boundingRect(a[i])
  x2, y2, w2, h2 =cv2.boundingRect(a[minIndex])
  center1=abs(int(x1+(w1/2))-center)
  middle1=abs(int(y1+(h1/2))-middle)
  center2=abs(int(x2+(w2/2))-center)
  middle2=abs(int(y2+(h2/2))-middle)
  if center1+middle1<center2+middle2:
    minIndex=i

m3=np.full(m1.shape,(255,255,255),np.uint8)
cv2.drawContours(m3,a,minIndex,(0,0,0),-1)
# m3=cv2.add(m1,m3)

text=pt.image_to_string(m3,"eng","")
print("辨識出來的問字：",text)
# cv2_imshow(m1)
cv2_imshow(m2)
cv2_imshow(m3)

# %%
from PIL import ImageFont, ImageDraw, Image
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
import time
import pytesseract as pt

m1=cv2.imread("my1.png",1)
text=pt.image_to_string(m1,"my","")
print("辨識出來的文字：",text)
cv2_imshow(m1)

# %%
# !python training.py

# %%
# !apt install libzbar-dev

# %%
# !pip install pyzbar

# %%
from PIL import ImageFont, ImageDraw, Image
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
import time
from pyzbar import pyzbar

m1=cv2.imread("11.png",1)
ret=pyzbar.decode(m1)
for d in ret:
  print("條碼類型：",d.type)
  try:
    print("條碼內容：",d.data.decode("utf-8").encode("sjis").decode("utf-8"))
  except:
    print("條碼內容：",d.data.decode("utf-8"))
  x,y,w,h=d.rect
  cv2.rectangle(m1, (x,y), (x+w,y+h), (0,0,255), 2)
  print("=============")
cv2_imshow(m1)

# %%
# !unzip haarcascades.zip

# %%
from PIL import ImageFont, ImageDraw, Image
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
import time

m1=cv2.imread("6.jpg",1)
p1=cv2.CascadeClassifier("haarcascades/haarcascade_frontalface_default.xml")
ret=p1.detectMultiScale(m1,minNeighbors=1,minSize=(10,10))
for x,y,w,h in ret:
  cv2.rectangle(m1, (x,y), (x+w,y+h), (0,0,255), 2)

cv2_imshow(m1)

# %%
# !unzip classifier_training_colab.zip

# %%
# !python ./classifier_training_colab/training.py

# %%
from PIL import ImageFont, ImageDraw, Image
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
import time

m1=cv2.imread("classifier_training_colab/Data/Image.jpg",1)
p1=cv2.CascadeClassifier("classifier_training_colab/xml/cascade.xml")
ret=p1.detectMultiScale(m1,minNeighbors=5,minSize=(10,10))
for x,y,w,h in ret:
  cv2.rectangle(m1, (x,y), (x+w,y+h), (0,0,255), 2)

cv2_imshow(m1)
# Out:
# <PIL.Image.Image image mode=RGB size=800x450 at 0x7F8581C8FF90>
